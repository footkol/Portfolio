# %% [markdown]
# # Cleaning The COUGHVID crowdsourcing dataset
# Cough audio signal classification has been successfully used to diagnose a variety of respiratory conditions, and there has been significant interest in leveraging Machine Learning (ML) to provide widespread COVID-19 screening. The COUGHVID dataset provides over 25,000 crowdsourced cough recordings representing a wide range of participant ages, genders, geographic locations, and COVID-19 statuses.
# __[The link to the article](https://www.nature.com/articles/s41597-021-00937-4)__

# %% [markdown]
# ## Initial data cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import librosa
import librosa.display

# %%
df = pd.read_csv('metadata_compiled.csv', index_col = 0)
df.head(10)
# Out:
#                                    uuid                          datetime  \
# 0  00014dcc-0f06-4c27-8c7b-737b18a2cf4c  2020-11-25T18:58:50.488301+00:00
# 1  00039425-7f3a-42aa-ac13-834aaa2b6b92  2020-04-13T21:30:59.801831+00:00
# 2  0007c6f1-5441-40e6-9aaf-a761d8f2da3b  2020-10-18T15:38:38.205870+00:00
# 3  00098cdb-4da1-4aa7-825a-4f1b9abc214b  2021-01-22T22:08:06.742577+00:00
# 4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a  2020-04-12T04:02:18.159383+00:00
# 5  0012c608-33d0-4ef7-bde3-75a0b1a0024e  2020-04-15T01:03:59.029326+00:00
# 6  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f  2020-04-13T22:23:06.997578+00:00
# 7  00196ba6-0087-484b-a104-3e8884599596  2021-05-28T15:47:24.337832+00:00
# 8  001c85a8-cc4d-4921-9297-848be52d4715  2020-04-17T15:24:35.822355+00:00
# 9  001d8e33-a4af-4edb-98ba-b03f891d9a6c  2020-05-13T01:27:42.552773+00:00
#
#    cough_detected  latitude  longitude   age  gender respiratory_condition  \
# 0          0.0155      48.9        2.4   NaN     NaN                   NaN
# 1          0.9609      31.3       34.8  15.0    male                 False
# 2          0.1643       NaN        NaN  46.0  female                 False
# 3          0.1133      47.4        9.4  66.0  female                 False
# 4          0.9301      40.0      -75.1  34.0    male                  True
# 5          0.0482     -16.5      -71.5   NaN     NaN                   NaN
# 6          0.9968       NaN        NaN  21.0    male                 False
# 7          0.3079       NaN        NaN   NaN     NaN                   NaN
# 8          0.0735      40.6       -3.6   NaN     NaN                   NaN
# 9          0.0306      13.8      -89.6   NaN  female                 False
#
#   fever_muscle_pain    status  ... quality_4 cough_type_4 dyspnea_4  \
# 0               NaN       NaN  ...       NaN          NaN       NaN
# 1             False   healthy  ...       NaN          NaN       NaN
# 2             False   healthy  ...       NaN          NaN       NaN
# 3             False   healthy  ...       NaN          NaN       NaN
# 4             False   healthy  ...       NaN          NaN       NaN
# 5               NaN       NaN  ...       NaN          NaN       NaN
# 6             False   healthy  ...       NaN          NaN       NaN
# 7               NaN       NaN  ...       NaN          NaN       NaN
# 8               NaN       NaN  ...       NaN          NaN       NaN
# 9              True  COVID-19  ...       NaN          NaN       NaN
#
#   wheezing_4 stridor_4 choking_4 congestion_4 nothing_4 diagnosis_4 severity_4
# 0        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 1        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 2        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 3        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 4        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 5        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 6        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 7        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 8        NaN       NaN       NaN          NaN       NaN         NaN        NaN
# 9        NaN       NaN       NaN          NaN       NaN         NaN        NaN
#
# [10 rows x 51 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34434 entries, 0 to 34433
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   uuid                   34434 non-null  object
#  1   datetime               34434 non-null  object
#  2   cough_detected         34434 non-null  float64
#  3   latitude               19431 non-null  float64
#  4   longitude              19431 non-null  float64
#  5   age                    19396 non-null  float64
#  6   gender                 20664 non-null  object
#  7   respiratory_condition  20664 non-null  object
#  8   fever_muscle_pain      20664 non-null  object
#  9   status                 20664 non-null  object
#  10  status_SSL             8331 non-null   object
#  11  quality_1              820 non-null    object
#  12  cough_type_1           820 non-null    object
#  13  dyspnea_1              820 non-null    object
#  14  wheezing_1             820 non-null    object
#  15  stridor_1              820 non-null    object
#  16  choking_1              820 non-null    object
#  17  congestion_1           820 non-null    object
#  18  nothing_1              820 non-null    object
#  19  diagnosis_1            820 non-null    object
#  20  severity_1             820 non-null    object
#  21  quality_2              820 non-null    object
#  22  cough_type_2           819 non-null    object
#  23  dyspnea_2              820 non-null    object
#  24  wheezing_2             820 non-null    object
#  25  stridor_2              820 non-null    object
#  26  choking_2              820 non-null    object
#  27  congestion_2           820 non-null    object
#  28  nothing_2              820 non-null    object
#  29  diagnosis_2            820 non-null    object
#  30  severity_2             820 non-null    object
#  31  quality_3              820 non-null    object
#  32  cough_type_3           795 non-null    object
#  33  dyspnea_3              820 non-null    object
#  34  wheezing_3             820 non-null    object
#  35  stridor_3              820 non-null    object
#  36  choking_3              820 non-null    object
#  37  congestion_3           820 non-null    object
#  38  nothing_3              820 non-null    object
#  39  diagnosis_3            793 non-null    object
#  40  severity_3             796 non-null    object
#  41  quality_4              820 non-null    object
#  42  cough_type_4           803 non-null    object
#  43  dyspnea_4              820 non-null    object
#  44  wheezing_4             820 non-null    object
#  45  stridor_4              820 non-null    object
#  46  choking_4              820 non-null    object
#  47  congestion_4           820 non-null    object
#  48  nothing_4              820 non-null    object
#  49  diagnosis_4            791 non-null    object
#  50  severity_4             802 non-null    object
# dtypes: float64(4), object(47)
# memory usage: 13.7+ MB

# %%
df.isnull().sum()
# Out:
# uuid                         0
# datetime                     0
# cough_detected               0
# latitude                 15003
# longitude                15003
# age                      15038
# gender                   13770
# respiratory_condition    13770
# fever_muscle_pain        13770
# status                   13770
# status_SSL               26103
# quality_1                33614
# cough_type_1             33614
# dyspnea_1                33614
# wheezing_1               33614
# stridor_1                33614
# choking_1                33614
# congestion_1             33614
# nothing_1                33614
# diagnosis_1              33614
# severity_1               33614
# quality_2                33614
# cough_type_2             33615
# dyspnea_2                33614
# wheezing_2               33614
# stridor_2                33614
# choking_2                33614
# congestion_2             33614
# nothing_2                33614
# diagnosis_2              33614
# severity_2               33614
# quality_3                33614
# cough_type_3             33639
# dyspnea_3                33614
# wheezing_3               33614
# stridor_3                33614
# choking_3                33614
# congestion_3             33614
# nothing_3                33614
# diagnosis_3              33641
# severity_3               33638
# quality_4                33614
# cough_type_4             33631
# dyspnea_4                33614
# wheezing_4               33614
# stridor_4                33614
# choking_4                33614
# congestion_4             33614
# nothing_4                33614
# diagnosis_4              33643
# severity_4               33632
# dtype: int64

# %%
#Removing unnecessary columns
df = df.drop(['datetime', 'longitude', 'latitude'], axis = 1)
df.columns
# Out:
# Index(['uuid', 'cough_detected', 'age', 'gender', 'respiratory_condition',
#        'fever_muscle_pain', 'status', 'status_SSL', 'quality_1',
#        'cough_type_1', 'dyspnea_1', 'wheezing_1', 'stridor_1', 'choking_1',
#        'congestion_1', 'nothing_1', 'diagnosis_1', 'severity_1', 'quality_2',
#        'cough_type_2', 'dyspnea_2', 'wheezing_2', 'stridor_2', 'choking_2',
#        'congestion_2', 'nothing_2', 'diagnosis_2', 'severity_2', 'quality_3',
#        'cough_type_3', 'dyspnea_3', 'wheezing_3', 'stridor_3', 'choking_3',
#        'congestion_3', 'nothing_3', 'diagnosis_3', 'severity_3', 'quality_4',
#        'cough_type_4', 'dyspnea_4', 'wheezing_4', 'stridor_4', 'choking_4',
#        'congestion_4', 'nothing_4', 'diagnosis_4', 'severity_4'],
#       dtype='object')

# %% [markdown]
# Let's find out which columns are numerical and which are categorical

# %%
numerical_cols = df.select_dtypes(include='number').columns
print('Numerical columns')
print(numerical_cols)
# Out:
# Numerical columns
# Index(['cough_detected', 'age'], dtype='object')

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
display('Categorical columns')
display(categorical_cols)
# Out:
# 'Categorical columns'
# Index(['uuid', 'gender', 'respiratory_condition', 'fever_muscle_pain',
#        'status', 'status_SSL', 'quality_1', 'cough_type_1', 'dyspnea_1',
#        'wheezing_1', 'stridor_1', 'choking_1', 'congestion_1', 'nothing_1',
#        'diagnosis_1', 'severity_1', 'quality_2', 'cough_type_2', 'dyspnea_2',
#        'wheezing_2', 'stridor_2', 'choking_2', 'congestion_2', 'nothing_2',
#        'diagnosis_2', 'severity_2', 'quality_3', 'cough_type_3', 'dyspnea_3',
#        'wheezing_3', 'stridor_3', 'choking_3', 'congestion_3', 'nothing_3',
#        'diagnosis_3', 'severity_3', 'quality_4', 'cough_type_4', 'dyspnea_4',
#        'wheezing_4', 'stridor_4', 'choking_4', 'congestion_4', 'nothing_4',
#        'diagnosis_4', 'severity_4'],
#       dtype='object')

# %%
#let's find out unique values in each categorical column (except for 'uuid' column)

for column in categorical_cols[1:]:
    unique_values = df[column].value_counts()
    non_null_values = df[column].count()
    display(f'Column: {column} - Non value values: {non_null_values}')
    display(unique_values)
    display()
# Out:
# 'Column: gender - Non value values: 20664'
# male      12850
# female     7682
# other       132
# Name: gender, dtype: int64
# 'Column: respiratory_condition - Non value values: 20664'
# False    17107
# True      3557
# Name: respiratory_condition, dtype: int64
# 'Column: fever_muscle_pain - Non value values: 20664'
# False    18179
# True      2485
# Name: fever_muscle_pain, dtype: int64
# 'Column: status - Non value values: 20664'
# healthy        15476
# symptomatic     3873
# COVID-19        1315
# Name: status, dtype: int64
# 'Column: status_SSL - Non value values: 8331'
# healthy     8046
# COVID-19     285
# Name: status_SSL, dtype: int64
# 'Column: quality_1 - Non value values: 820'
# ok          614
# poor        156
# good         32
# no_cough     18
# Name: quality_1, dtype: int64
# 'Column: cough_type_1 - Non value values: 820'
# dry        425
# unknown    323
# wet         72
# Name: cough_type_1, dtype: int64
# 'Column: dyspnea_1 - Non value values: 820'
# False    815
# True       5
# Name: dyspnea_1, dtype: int64
# 'Column: wheezing_1 - Non value values: 820'
# False    765
# True      55
# Name: wheezing_1, dtype: int64
# 'Column: stridor_1 - Non value values: 820'
# False    820
# Name: stridor_1, dtype: int64
# 'Column: choking_1 - Non value values: 820'
# False    818
# True       2
# Name: choking_1, dtype: int64
# 'Column: congestion_1 - Non value values: 820'
# False    806
# True      14
# Name: congestion_1, dtype: int64
# 'Column: nothing_1 - Non value values: 820'
# True     746
# False     74
# Name: nothing_1, dtype: int64
# 'Column: diagnosis_1 - Non value values: 820'
# COVID-19               279
# healthy_cough          259
# lower_infection        244
# upper_infection         23
# obstructive_disease     15
# Name: diagnosis_1, dtype: int64
# 'Column: severity_1 - Non value values: 820'
# mild           521
# pseudocough    249
# severe          34
# unknown         16
# Name: severity_1, dtype: int64
# 'Column: quality_2 - Non value values: 820'
# good        422
# ok          286
# poor         93
# no_cough     19
# Name: quality_2, dtype: int64
# 'Column: cough_type_2 - Non value values: 819'
# dry        600
# wet        133
# unknown     86
# Name: cough_type_2, dtype: int64
# 'Column: dyspnea_2 - Non value values: 820'
# False    724
# True      96
# Name: dyspnea_2, dtype: int64
# 'Column: wheezing_2 - Non value values: 820'
# False    737
# True      83
# Name: wheezing_2, dtype: int64
# 'Column: stridor_2 - Non value values: 820'
# False    788
# True      32
# Name: stridor_2, dtype: int64
# 'Column: choking_2 - Non value values: 820'
# False    795
# True      25
# Name: choking_2, dtype: int64
# 'Column: congestion_2 - Non value values: 820'
# False    797
# True      23
# Name: congestion_2, dtype: int64
# 'Column: nothing_2 - Non value values: 820'
# True     586
# False    234
# Name: nothing_2, dtype: int64
# 'Column: diagnosis_2 - Non value values: 820'
# COVID-19               285
# upper_infection        183
# lower_infection        173
# obstructive_disease    112
# healthy_cough           67
# Name: diagnosis_2, dtype: int64
# 'Column: severity_2 - Non value values: 820'
# mild           572
# unknown        139
# severe          59
# pseudocough     50
# Name: severity_2, dtype: int64
# 'Column: quality_3 - Non value values: 820'
# good        749
# ok           31
# no_cough     25
# poor         15
# Name: quality_3, dtype: int64
# 'Column: cough_type_3 - Non value values: 795'
# dry        358
# wet        291
# unknown    146
# Name: cough_type_3, dtype: int64
# 'Column: dyspnea_3 - Non value values: 820'
# False    818
# True       2
# Name: dyspnea_3, dtype: int64
# 'Column: wheezing_3 - Non value values: 820'
# False    818
# True       2
# Name: wheezing_3, dtype: int64
# 'Column: stridor_3 - Non value values: 820'
# False    819
# True       1
# Name: stridor_3, dtype: int64
# 'Column: choking_3 - Non value values: 820'
# False    820
# Name: choking_3, dtype: int64
# 'Column: congestion_3 - Non value values: 820'
# False    817
# True       3
# Name: congestion_3, dtype: int64
# 'Column: nothing_3 - Non value values: 820'
# True     787
# False     33
# Name: nothing_3, dtype: int64
# 'Column: diagnosis_3 - Non value values: 793'
# upper_infection        364
# healthy_cough          199
# lower_infection        194
# obstructive_disease     35
# COVID-19                 1
# Name: diagnosis_3, dtype: int64
# 'Column: severity_3 - Non value values: 796'
# mild           447
# pseudocough    196
# severe         105
# unknown         48
# Name: severity_3, dtype: int64
# 'Column: quality_4 - Non value values: 820'
# good        664
# ok          111
# poor         28
# no_cough     17
# Name: quality_4, dtype: int64
# 'Column: cough_type_4 - Non value values: 803'
# dry        654
# wet        120
# unknown     29
# Name: cough_type_4, dtype: int64
# 'Column: dyspnea_4 - Non value values: 820'
# False    806
# True      14
# Name: dyspnea_4, dtype: int64
# 'Column: wheezing_4 - Non value values: 820'
# False    804
# True      16
# Name: wheezing_4, dtype: int64
# 'Column: stridor_4 - Non value values: 820'
# False    810
# True      10
# Name: stridor_4, dtype: int64
# 'Column: choking_4 - Non value values: 820'
# False    820
# Name: choking_4, dtype: int64
# 'Column: congestion_4 - Non value values: 820'
# False    743
# True      77
# Name: congestion_4, dtype: int64
# 'Column: nothing_4 - Non value values: 820'
# True     684
# False    136
# Name: nothing_4, dtype: int64
# 'Column: diagnosis_4 - Non value values: 791'
# upper_infection        313
# healthy_cough          221
# lower_infection        121
# COVID-19                84
# obstructive_disease     52
# Name: diagnosis_4, dtype: int64
# 'Column: severity_4 - Non value values: 802'
# mild           472
# pseudocough    221
# severe          69
# unknown         40
# Name: severity_4, dtype: int64

# %% [markdown]
# ## Analysing 'quality' columns
# To enhance the quality of the dataset with clinically validated information, four expert physicians revised 1000 recordings, selecting one of the predefined options for audio quality:
#  - Good: Cough present with minimal background noise
#  - Ok: Cough present with background noise
#  - Poor: Cough present with significant background noise
#  - No cough present

# %%
#Let's analyse quality columns by separating them into dataframe
quality_df = pd.DataFrame().assign(quality_1 = df["quality_1"], 
                                   quality_2 = df["quality_2"], 
                                   quality_3 = df["quality_3"], 
                                   quality_4 = df["quality_4"])
quality_df.head(10)
# Out:
#   quality_1 quality_2 quality_3 quality_4
# 0       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN
# 5       NaN       NaN       NaN       NaN
# 6       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN
# 9       NaN       NaN       NaN       NaN

# %%
# There are rows with all NaNs, let's drop them
quality_df = quality_df.dropna(how='all')
quality_df
# Out:
#       quality_1 quality_2 quality_3 quality_4
# 14          NaN       NaN       NaN      good
# 16          NaN       NaN      good       NaN
# 42          NaN      good       NaN       NaN
# 51           ok       NaN       NaN       NaN
# 70          NaN       NaN      good       NaN
# ...         ...       ...       ...       ...
# 34407       NaN       NaN      good       NaN
# 34411  no_cough       NaN       NaN       NaN
# 34413       NaN       NaN       NaN        ok
# 34421       NaN       NaN       NaN      poor
# 34425       NaN       NaN       NaN      good
#
# [2890 rows x 4 columns]

# %%
#checking unique values in each column
for column in quality_df:
    unique_values = quality_df[column].value_counts()
    display(unique_values)
# Out:
# ok          614
# poor        156
# good         32
# no_cough     18
# Name: quality_1, dtype: int64
# good        422
# ok          286
# poor         93
# no_cough     19
# Name: quality_2, dtype: int64
# good        749
# ok           31
# no_cough     25
# poor         15
# Name: quality_3, dtype: int64
# good        664
# ok          111
# poor         28
# no_cough     17
# Name: quality_4, dtype: int64

# %%
#Let's create separate data set where quality value is 'good' or 'ok'
fair_quality_df = quality_df[quality_df.isin(['good','ok']).any(axis=1)]
fair_quality_df
# Out:
#       quality_1 quality_2 quality_3 quality_4
# 14          NaN       NaN       NaN      good
# 16          NaN       NaN      good       NaN
# 42          NaN      good       NaN       NaN
# 51           ok       NaN       NaN       NaN
# 70          NaN       NaN      good       NaN
# ...         ...       ...       ...       ...
# 34380        ok       NaN       NaN       NaN
# 34394       NaN       NaN      good       NaN
# 34407       NaN       NaN      good       NaN
# 34413       NaN       NaN       NaN        ok
# 34425       NaN       NaN       NaN      good
#
# [2573 rows x 4 columns]

# %%
#Identifying rows where more than one expert has provided audio quality check
expert_fair_quality = fair_quality_df[fair_quality_df.notnull().sum(axis=1)>1]
expert_fair_quality
# Out:
#       quality_1 quality_2 quality_3 quality_4
# 186        good      good      good      good
# 266        poor        ok      good      good
# 2077         ok      poor      good      good
# 2079         ok        ok      good      good
# 3486       poor      poor      good        ok
# ...         ...       ...       ...       ...
# 33151        ok      good      good      good
# 33544      poor      good      good      good
# 34099        ok      good      good      good
# 34290        ok        ok      good      good
# 34319        ok      good      good      good
#
# [127 rows x 4 columns]

# %%
#this is an example of the row containing all four experts' assessments. 
#We may need it later in our analysis

df.iloc[186]
# Out:
# uuid                     01567151-7bb2-45ee-9aa8-a1332b5941ea
# cough_detected                                          0.982
# age                                                       NaN
# gender                                                    NaN
# respiratory_condition                                     NaN
# fever_muscle_pain                                         NaN
# status                                                    NaN
# status_SSL                                                NaN
# quality_1                                                good
# cough_type_1                                              dry
# dyspnea_1                                               False
# wheezing_1                                              False
# stridor_1                                               False
# choking_1                                                True
# congestion_1                                            False
# nothing_1                                               False
# diagnosis_1                                          COVID-19
# severity_1                                               mild
# quality_2                                                good
# cough_type_2                                              dry
# dyspnea_2                                                True
# wheezing_2                                              False
# stridor_2                                               False
# choking_2                                               False
# congestion_2                                            False
# nothing_2                                               False
# diagnosis_2                                          COVID-19
# severity_2                                               mild
# quality_3                                                good
# cough_type_3                                              wet
# dyspnea_3                                               False
# wheezing_3                                              False
# stridor_3                                               False
# choking_3                                               False
# congestion_3                                            False
# nothing_3                                               False
# diagnosis_3                                   lower_infection
# severity_3                                             severe
# quality_4                                                good
# cough_type_4                                              dry
# dyspnea_4                                               False
# wheezing_4                                              False
# stridor_4                                               False
# choking_4                                               False
# congestion_4                                            False
# nothing_4                                                True
# diagnosis_4                                   upper_infection
# severity_4                                               mild
# Name: 186, dtype: object

# %% [markdown]
# ## Exploring records with cough value of more than 0.8
# It is recommended using a cough_detected value of 0.8 because, this threshold exhibits an average precision of 95.4%. Therefore, only 4.6% of recordings with a cough_detected probability greater than 0.8 can be expected to contain non-cough events, which is not a large enough portion of the dataset to significantly bias cough classification algorithms.

# %%
threshold_value_df = df[df['cough_detected']>=0.8]
threshold_value_df
# Out:
#                                        uuid  cough_detected   age  gender  \
# 1      00039425-7f3a-42aa-ac13-834aaa2b6b92          0.9609  15.0    male
# 4      0009eb28-d8be-4dc1-92bb-907e53bc5c7a          0.9301  34.0    male
# 6      001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f          0.9968  21.0    male
# 12     0028b68c-aca4-4f4f-bb1d-cb4ed5bbd952          0.8937  28.0  female
# 13     00291cce-36a0-4a29-9e2d-c1d96ca17242          0.9883  15.0    male
# ...                                     ...             ...   ...     ...
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
# 34426  ffeea120-92a4-40f9-b692-c3865c7a983f          0.9784  22.0  female
# 34428  fff30afc-db62-4408-a585-07ca9a254fcc          0.9698   NaN     NaN
# 34432  fffce9f0-a5e8-4bee-b13b-c671aac4a61c          0.9754   NaN     NaN
# 34433  fffd1834-6cf2-4782-bb30-04c31b46a1fe          0.9754  22.0  female
#
#       respiratory_condition fever_muscle_pain   status status_SSL quality_1  \
# 1                     False             False  healthy    healthy       NaN
# 4                      True             False  healthy    healthy       NaN
# 6                     False             False  healthy    healthy       NaN
# 12                    False             False  healthy    healthy       NaN
# 13                    False             False  healthy        NaN       NaN
# ...                     ...               ...      ...        ...       ...
# 34425                 False             False  healthy    healthy       NaN
# 34426                 False             False  healthy    healthy       NaN
# 34428                   NaN               NaN      NaN        NaN       NaN
# 34432                   NaN               NaN      NaN        NaN       NaN
# 34433                 False             False  healthy        NaN       NaN
#
#       cough_type_1  ... quality_4 cough_type_4 dyspnea_4 wheezing_4 stridor_4  \
# 1              NaN  ...       NaN          NaN       NaN        NaN       NaN
# 4              NaN  ...       NaN          NaN       NaN        NaN       NaN
# 6              NaN  ...       NaN          NaN       NaN        NaN       NaN
# 12             NaN  ...       NaN          NaN       NaN        NaN       NaN
# 13             NaN  ...       NaN          NaN       NaN        NaN       NaN
# ...            ...  ...       ...          ...       ...        ...       ...
# 34425          NaN  ...      good          dry     False      False     False
# 34426          NaN  ...       NaN          NaN       NaN        NaN       NaN
# 34428          NaN  ...       NaN          NaN       NaN        NaN       NaN
# 34432          NaN  ...       NaN          NaN       NaN        NaN       NaN
# 34433          NaN  ...       NaN          NaN       NaN        NaN       NaN
#
#       choking_4 congestion_4 nothing_4    diagnosis_4   severity_4
# 1           NaN          NaN       NaN            NaN          NaN
# 4           NaN          NaN       NaN            NaN          NaN
# 6           NaN          NaN       NaN            NaN          NaN
# 12          NaN          NaN       NaN            NaN          NaN
# 13          NaN          NaN       NaN            NaN          NaN
# ...         ...          ...       ...            ...          ...
# 34425     False        False      True  healthy_cough  pseudocough
# 34426       NaN          NaN       NaN            NaN          NaN
# 34428       NaN          NaN       NaN            NaN          NaN
# 34432       NaN          NaN       NaN            NaN          NaN
# 34433       NaN          NaN       NaN            NaN          NaN
#
# [18544 rows x 48 columns]

# %%
#Let's remove all the rows without expert's assessments
quality_expert_df = threshold_value_df.dropna(
    subset = ['quality_1', 'quality_2', 'quality_3', 'quality_4'], 
    how='all')
quality_expert_df
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34421  ffe0658f-bade-4654-ad79-40a468aabb03          0.9846  22.0    male
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL  \
# 14                     True             False  symptomatic    healthy
# 16                      NaN               NaN          NaN        NaN
# 42                    False             False      healthy    healthy
# 70                    False             False      healthy    healthy
# 71                    False             False  symptomatic        NaN
# ...                     ...               ...          ...        ...
# 34394                   NaN               NaN          NaN        NaN
# 34407                 False             False  symptomatic        NaN
# 34413                 False             False      healthy    healthy
# 34421                  True              True     COVID-19        NaN
# 34425                 False             False      healthy    healthy
#
#       quality_1 cough_type_1  ... quality_4 cough_type_4 dyspnea_4 wheezing_4  \
# 14          NaN          NaN  ...      good          dry     False      False
# 16          NaN          NaN  ...       NaN          NaN       NaN        NaN
# 42          NaN          NaN  ...       NaN          NaN       NaN        NaN
# 70          NaN          NaN  ...       NaN          NaN       NaN        NaN
# 71          NaN          NaN  ...       NaN          NaN       NaN        NaN
# ...         ...          ...  ...       ...          ...       ...        ...
# 34394       NaN          NaN  ...       NaN          NaN       NaN        NaN
# 34407       NaN          NaN  ...       NaN          NaN       NaN        NaN
# 34413       NaN          NaN  ...        ok          dry     False      False
# 34421       NaN          NaN  ...      poor      unknown     False      False
# 34425       NaN          NaN  ...      good          dry     False      False
#
#       stridor_4 choking_4 congestion_4 nothing_4      diagnosis_4   severity_4
# 14        False     False        False      True  upper_infection         mild
# 16          NaN       NaN          NaN       NaN              NaN          NaN
# 42          NaN       NaN          NaN       NaN              NaN          NaN
# 70          NaN       NaN          NaN       NaN              NaN          NaN
# 71          NaN       NaN          NaN       NaN              NaN          NaN
# ...         ...       ...          ...       ...              ...          ...
# 34394       NaN       NaN          NaN       NaN              NaN          NaN
# 34407       NaN       NaN          NaN       NaN              NaN          NaN
# 34413     False     False        False      True         COVID-19         mild
# 34421     False     False        False     False              NaN      unknown
# 34425     False     False        False      True    healthy_cough  pseudocough
#
# [2481 rows x 48 columns]

# %%
#Identifying rows where audio quality is either 'good' or 'ok'
good_quality_expert_df = quality_expert_df[quality_expert_df.isin(
    {'quality_1': ['good','ok'],
    'quality_2': ['good','ok'],
    'quality_3': ['good','ok'],
    'quality_4': ['good','ok']}).any(axis=1)]

good_quality_expert_df
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL  \
# 14                     True             False  symptomatic    healthy
# 16                      NaN               NaN          NaN        NaN
# 42                    False             False      healthy    healthy
# 70                    False             False      healthy    healthy
# 71                    False             False  symptomatic        NaN
# ...                     ...               ...          ...        ...
# 34380                 False             False      healthy        NaN
# 34394                   NaN               NaN          NaN        NaN
# 34407                 False             False  symptomatic        NaN
# 34413                 False             False      healthy    healthy
# 34425                 False             False      healthy    healthy
#
#       quality_1 cough_type_1  ... quality_4 cough_type_4 dyspnea_4 wheezing_4  \
# 14          NaN          NaN  ...      good          dry     False      False
# 16          NaN          NaN  ...       NaN          NaN       NaN        NaN
# 42          NaN          NaN  ...       NaN          NaN       NaN        NaN
# 70          NaN          NaN  ...       NaN          NaN       NaN        NaN
# 71          NaN          NaN  ...       NaN          NaN       NaN        NaN
# ...         ...          ...  ...       ...          ...       ...        ...
# 34380        ok          dry  ...       NaN          NaN       NaN        NaN
# 34394       NaN          NaN  ...       NaN          NaN       NaN        NaN
# 34407       NaN          NaN  ...       NaN          NaN       NaN        NaN
# 34413       NaN          NaN  ...        ok          dry     False      False
# 34425       NaN          NaN  ...      good          dry     False      False
#
#       stridor_4 choking_4 congestion_4 nothing_4      diagnosis_4   severity_4
# 14        False     False        False      True  upper_infection         mild
# 16          NaN       NaN          NaN       NaN              NaN          NaN
# 42          NaN       NaN          NaN       NaN              NaN          NaN
# 70          NaN       NaN          NaN       NaN              NaN          NaN
# 71          NaN       NaN          NaN       NaN              NaN          NaN
# ...         ...       ...          ...       ...              ...          ...
# 34380       NaN       NaN          NaN       NaN              NaN          NaN
# 34394       NaN       NaN          NaN       NaN              NaN          NaN
# 34407       NaN       NaN          NaN       NaN              NaN          NaN
# 34413     False     False        False      True         COVID-19         mild
# 34425     False     False        False      True    healthy_cough  pseudocough
#
# [2269 rows x 48 columns]

# %% [markdown]
# ## Analysing each expert's dataframe
# In order to create a dataframe which we can use to train ML model, we should first split existing dataframe into four dataframes representing each expert, unify columns' names and finaly combine them into single dataframe again.

# %%
#removing irrelevant to expert 1 columns
columns_remove = ['cough_type_2','severity_2','dyspnea_2','wheezing_2','stridor_2','choking_2','congestion_2','nothing_2','diagnosis_2', 'quality_2',
                      'cough_type_3','severity_3','dyspnea_3','wheezing_3','stridor_3','choking_3','congestion_3','nothing_3','diagnosis_3', 'quality_3',
                      'cough_type_4','severity_4','dyspnea_4','wheezing_4','stridor_4','choking_4','congestion_4','nothing_4','diagnosis_4', 'quality_4']
 
expert_1 = good_quality_expert_df.drop(columns_remove, axis =1)
expert_1
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL  \
# 14                     True             False  symptomatic    healthy
# 16                      NaN               NaN          NaN        NaN
# 42                    False             False      healthy    healthy
# 70                    False             False      healthy    healthy
# 71                    False             False  symptomatic        NaN
# ...                     ...               ...          ...        ...
# 34380                 False             False      healthy        NaN
# 34394                   NaN               NaN          NaN        NaN
# 34407                 False             False  symptomatic        NaN
# 34413                 False             False      healthy    healthy
# 34425                 False             False      healthy    healthy
#
#       quality_1 cough_type_1 dyspnea_1 wheezing_1 stridor_1 choking_1  \
# 14          NaN          NaN       NaN        NaN       NaN       NaN
# 16          NaN          NaN       NaN        NaN       NaN       NaN
# 42          NaN          NaN       NaN        NaN       NaN       NaN
# 70          NaN          NaN       NaN        NaN       NaN       NaN
# 71          NaN          NaN       NaN        NaN       NaN       NaN
# ...         ...          ...       ...        ...       ...       ...
# 34380        ok          dry     False      False     False     False
# 34394       NaN          NaN       NaN        NaN       NaN       NaN
# 34407       NaN          NaN       NaN        NaN       NaN       NaN
# 34413       NaN          NaN       NaN        NaN       NaN       NaN
# 34425       NaN          NaN       NaN        NaN       NaN       NaN
#
#       congestion_1 nothing_1 diagnosis_1 severity_1
# 14             NaN       NaN         NaN        NaN
# 16             NaN       NaN         NaN        NaN
# 42             NaN       NaN         NaN        NaN
# 70             NaN       NaN         NaN        NaN
# 71             NaN       NaN         NaN        NaN
# ...            ...       ...         ...        ...
# 34380        False     False    COVID-19       mild
# 34394          NaN       NaN         NaN        NaN
# 34407          NaN       NaN         NaN        NaN
# 34413          NaN       NaN         NaN        NaN
# 34425          NaN       NaN         NaN        NaN
#
# [2269 rows x 18 columns]

# %%
#removing irrelevant to expert 2 columns
columns_remove = ['cough_type_1','severity_1','dyspnea_1','wheezing_1','stridor_1','choking_1','congestion_1','nothing_1','diagnosis_1', 'quality_1',
                      'cough_type_3','severity_3','dyspnea_3','wheezing_3','stridor_3','choking_3','congestion_3','nothing_3','diagnosis_3', 'quality_3',
                      'cough_type_4','severity_4','dyspnea_4','wheezing_4','stridor_4','choking_4','congestion_4','nothing_4','diagnosis_4', 'quality_4']
expert_2 = good_quality_expert_df.drop(columns_remove, axis =1)
expert_2
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL  \
# 14                     True             False  symptomatic    healthy
# 16                      NaN               NaN          NaN        NaN
# 42                    False             False      healthy    healthy
# 70                    False             False      healthy    healthy
# 71                    False             False  symptomatic        NaN
# ...                     ...               ...          ...        ...
# 34380                 False             False      healthy        NaN
# 34394                   NaN               NaN          NaN        NaN
# 34407                 False             False  symptomatic        NaN
# 34413                 False             False      healthy    healthy
# 34425                 False             False      healthy    healthy
#
#       quality_2 cough_type_2 dyspnea_2 wheezing_2 stridor_2 choking_2  \
# 14          NaN          NaN       NaN        NaN       NaN       NaN
# 16          NaN          NaN       NaN        NaN       NaN       NaN
# 42         good          dry     False      False     False     False
# 70          NaN          NaN       NaN        NaN       NaN       NaN
# 71          NaN          NaN       NaN        NaN       NaN       NaN
# ...         ...          ...       ...        ...       ...       ...
# 34380       NaN          NaN       NaN        NaN       NaN       NaN
# 34394       NaN          NaN       NaN        NaN       NaN       NaN
# 34407       NaN          NaN       NaN        NaN       NaN       NaN
# 34413       NaN          NaN       NaN        NaN       NaN       NaN
# 34425       NaN          NaN       NaN        NaN       NaN       NaN
#
#       congestion_2 nothing_2      diagnosis_2 severity_2
# 14             NaN       NaN              NaN        NaN
# 16             NaN       NaN              NaN        NaN
# 42           False      True  lower_infection       mild
# 70             NaN       NaN              NaN        NaN
# 71             NaN       NaN              NaN        NaN
# ...            ...       ...              ...        ...
# 34380          NaN       NaN              NaN        NaN
# 34394          NaN       NaN              NaN        NaN
# 34407          NaN       NaN              NaN        NaN
# 34413          NaN       NaN              NaN        NaN
# 34425          NaN       NaN              NaN        NaN
#
# [2269 rows x 18 columns]

# %%
#removing irrelevant to expert 3 columns
columns_remove = ['cough_type_2','severity_2','dyspnea_2','wheezing_2','stridor_2','choking_2','congestion_2','nothing_2','diagnosis_2', 'quality_2',
                      'cough_type_1','severity_1','dyspnea_1','wheezing_1','stridor_1','choking_1','congestion_1','nothing_1','diagnosis_1', 'quality_1',
                      'cough_type_4','severity_4','dyspnea_4','wheezing_4','stridor_4','choking_4','congestion_4','nothing_4','diagnosis_4', 'quality_4']
expert_3 = good_quality_expert_df.drop(columns_remove, axis =1)
expert_3
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL  \
# 14                     True             False  symptomatic    healthy
# 16                      NaN               NaN          NaN        NaN
# 42                    False             False      healthy    healthy
# 70                    False             False      healthy    healthy
# 71                    False             False  symptomatic        NaN
# ...                     ...               ...          ...        ...
# 34380                 False             False      healthy        NaN
# 34394                   NaN               NaN          NaN        NaN
# 34407                 False             False  symptomatic        NaN
# 34413                 False             False      healthy    healthy
# 34425                 False             False      healthy    healthy
#
#       quality_3 cough_type_3 dyspnea_3 wheezing_3 stridor_3 choking_3  \
# 14          NaN          NaN       NaN        NaN       NaN       NaN
# 16         good      unknown     False      False     False     False
# 42          NaN          NaN       NaN        NaN       NaN       NaN
# 70         good          wet     False      False      True     False
# 71         good          wet     False      False     False     False
# ...         ...          ...       ...        ...       ...       ...
# 34380       NaN          NaN       NaN        NaN       NaN       NaN
# 34394      good          dry     False      False     False     False
# 34407      good          wet     False      False     False     False
# 34413       NaN          NaN       NaN        NaN       NaN       NaN
# 34425       NaN          NaN       NaN        NaN       NaN       NaN
#
#       congestion_3 nothing_3      diagnosis_3   severity_3
# 14             NaN       NaN              NaN          NaN
# 16           False      True    healthy_cough  pseudocough
# 42             NaN       NaN              NaN          NaN
# 70           False     False  lower_infection         mild
# 71           False      True    healthy_cough  pseudocough
# ...            ...       ...              ...          ...
# 34380          NaN       NaN              NaN          NaN
# 34394        False      True  upper_infection         mild
# 34407        False      True  upper_infection         mild
# 34413          NaN       NaN              NaN          NaN
# 34425          NaN       NaN              NaN          NaN
#
# [2269 rows x 18 columns]

# %%
#removing irrelevant to expert 4 columns
columns_remove = ['cough_type_2','severity_2','dyspnea_2','wheezing_2','stridor_2','choking_2','congestion_2','nothing_2','diagnosis_2', 'quality_2',
                      'cough_type_3','severity_3','dyspnea_3','wheezing_3','stridor_3','choking_3','congestion_3','nothing_3','diagnosis_3', 'quality_3',
                      'cough_type_1','severity_1','dyspnea_1','wheezing_1','stridor_1','choking_1','congestion_1','nothing_1','diagnosis_1', 'quality_1']
expert_4 = good_quality_expert_df.drop(columns_remove, axis =1)
expert_4
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL  \
# 14                     True             False  symptomatic    healthy
# 16                      NaN               NaN          NaN        NaN
# 42                    False             False      healthy    healthy
# 70                    False             False      healthy    healthy
# 71                    False             False  symptomatic        NaN
# ...                     ...               ...          ...        ...
# 34380                 False             False      healthy        NaN
# 34394                   NaN               NaN          NaN        NaN
# 34407                 False             False  symptomatic        NaN
# 34413                 False             False      healthy    healthy
# 34425                 False             False      healthy    healthy
#
#       quality_4 cough_type_4 dyspnea_4 wheezing_4 stridor_4 choking_4  \
# 14         good          dry     False      False     False     False
# 16          NaN          NaN       NaN        NaN       NaN       NaN
# 42          NaN          NaN       NaN        NaN       NaN       NaN
# 70          NaN          NaN       NaN        NaN       NaN       NaN
# 71          NaN          NaN       NaN        NaN       NaN       NaN
# ...         ...          ...       ...        ...       ...       ...
# 34380       NaN          NaN       NaN        NaN       NaN       NaN
# 34394       NaN          NaN       NaN        NaN       NaN       NaN
# 34407       NaN          NaN       NaN        NaN       NaN       NaN
# 34413        ok          dry     False      False     False     False
# 34425      good          dry     False      False     False     False
#
#       congestion_4 nothing_4      diagnosis_4   severity_4
# 14           False      True  upper_infection         mild
# 16             NaN       NaN              NaN          NaN
# 42             NaN       NaN              NaN          NaN
# 70             NaN       NaN              NaN          NaN
# 71             NaN       NaN              NaN          NaN
# ...            ...       ...              ...          ...
# 34380          NaN       NaN              NaN          NaN
# 34394          NaN       NaN              NaN          NaN
# 34407          NaN       NaN              NaN          NaN
# 34413        False      True         COVID-19         mild
# 34425        False      True    healthy_cough  pseudocough
#
# [2269 rows x 18 columns]

# %%
#unifying columns' names
def remove_last_two_characters(df, column_names):
    rename_dict = {col: col[:-2] for col in column_names}
    df.rename(columns=rename_dict, inplace=True)

column_names = [ 'cough_type_1','severity_1','dyspnea_1','wheezing_1','stridor_1','choking_1','congestion_1','nothing_1','diagnosis_1', 'quality_1']

remove_last_two_characters(expert_1, column_names)

# %%
#verifying results
expert_1
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL quality  \
# 14                     True             False  symptomatic    healthy     NaN
# 16                      NaN               NaN          NaN        NaN     NaN
# 42                    False             False      healthy    healthy     NaN
# 70                    False             False      healthy    healthy     NaN
# 71                    False             False  symptomatic        NaN     NaN
# ...                     ...               ...          ...        ...     ...
# 34380                 False             False      healthy        NaN      ok
# 34394                   NaN               NaN          NaN        NaN     NaN
# 34407                 False             False  symptomatic        NaN     NaN
# 34413                 False             False      healthy    healthy     NaN
# 34425                 False             False      healthy    healthy     NaN
#
#       cough_type dyspnea wheezing stridor choking congestion nothing  \
# 14           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 16           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 42           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 70           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 71           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# ...          ...     ...      ...     ...     ...        ...     ...
# 34380        dry   False    False   False   False      False   False
# 34394        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34407        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34413        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34425        NaN     NaN      NaN     NaN     NaN        NaN     NaN
#
#       diagnosis severity
# 14          NaN      NaN
# 16          NaN      NaN
# 42          NaN      NaN
# 70          NaN      NaN
# 71          NaN      NaN
# ...         ...      ...
# 34380  COVID-19     mild
# 34394       NaN      NaN
# 34407       NaN      NaN
# 34413       NaN      NaN
# 34425       NaN      NaN
#
# [2269 rows x 18 columns]

# %%
column_names = ['cough_type_2','severity_2','dyspnea_2','wheezing_2','stridor_2','choking_2','congestion_2','nothing_2','diagnosis_2', 'quality_2']
remove_last_two_characters(expert_2, column_names)

#verifying results once again
expert_2
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL quality  \
# 14                     True             False  symptomatic    healthy     NaN
# 16                      NaN               NaN          NaN        NaN     NaN
# 42                    False             False      healthy    healthy    good
# 70                    False             False      healthy    healthy     NaN
# 71                    False             False  symptomatic        NaN     NaN
# ...                     ...               ...          ...        ...     ...
# 34380                 False             False      healthy        NaN     NaN
# 34394                   NaN               NaN          NaN        NaN     NaN
# 34407                 False             False  symptomatic        NaN     NaN
# 34413                 False             False      healthy    healthy     NaN
# 34425                 False             False      healthy    healthy     NaN
#
#       cough_type dyspnea wheezing stridor choking congestion nothing  \
# 14           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 16           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 42           dry   False    False   False   False      False    True
# 70           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 71           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# ...          ...     ...      ...     ...     ...        ...     ...
# 34380        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34394        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34407        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34413        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34425        NaN     NaN      NaN     NaN     NaN        NaN     NaN
#
#              diagnosis severity
# 14                 NaN      NaN
# 16                 NaN      NaN
# 42     lower_infection     mild
# 70                 NaN      NaN
# 71                 NaN      NaN
# ...                ...      ...
# 34380              NaN      NaN
# 34394              NaN      NaN
# 34407              NaN      NaN
# 34413              NaN      NaN
# 34425              NaN      NaN
#
# [2269 rows x 18 columns]

# %%
column_names = ['cough_type_3','severity_3','dyspnea_3','wheezing_3','stridor_3','choking_3','congestion_3','nothing_3','diagnosis_3', 'quality_3']
remove_last_two_characters(expert_3, column_names)

expert_3
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL quality  \
# 14                     True             False  symptomatic    healthy     NaN
# 16                      NaN               NaN          NaN        NaN    good
# 42                    False             False      healthy    healthy     NaN
# 70                    False             False      healthy    healthy    good
# 71                    False             False  symptomatic        NaN    good
# ...                     ...               ...          ...        ...     ...
# 34380                 False             False      healthy        NaN     NaN
# 34394                   NaN               NaN          NaN        NaN    good
# 34407                 False             False  symptomatic        NaN    good
# 34413                 False             False      healthy    healthy     NaN
# 34425                 False             False      healthy    healthy     NaN
#
#       cough_type dyspnea wheezing stridor choking congestion nothing  \
# 14           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 16       unknown   False    False   False   False      False    True
# 42           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 70           wet   False    False    True   False      False   False
# 71           wet   False    False   False   False      False    True
# ...          ...     ...      ...     ...     ...        ...     ...
# 34380        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34394        dry   False    False   False   False      False    True
# 34407        wet   False    False   False   False      False    True
# 34413        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34425        NaN     NaN      NaN     NaN     NaN        NaN     NaN
#
#              diagnosis     severity
# 14                 NaN          NaN
# 16       healthy_cough  pseudocough
# 42                 NaN          NaN
# 70     lower_infection         mild
# 71       healthy_cough  pseudocough
# ...                ...          ...
# 34380              NaN          NaN
# 34394  upper_infection         mild
# 34407  upper_infection         mild
# 34413              NaN          NaN
# 34425              NaN          NaN
#
# [2269 rows x 18 columns]

# %%
column_names = ['cough_type_4','severity_4','dyspnea_4','wheezing_4','stridor_4','choking_4','congestion_4','nothing_4','diagnosis_4', 'quality_4']
remove_last_two_characters(expert_4, column_names)

expert_4
# Out:
#                                        uuid  cough_detected   age  gender  \
# 14     0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0    male
# 16     002db0bd-e57f-4c30-ade0-16640d424eb7          0.9536   NaN     NaN
# 42     005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0  female
# 70     008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0  female
# 71     008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0    male
# ...                                     ...             ...   ...     ...
# 34380  ff8bfcc9-3df2-4752-8280-63f023fba31c          0.9830   NaN  female
# 34394  ffa718e8-da65-4602-8da8-cda7cdc568f2          0.9735   NaN     NaN
# 34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0    male
# 34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#       respiratory_condition fever_muscle_pain       status status_SSL quality  \
# 14                     True             False  symptomatic    healthy    good
# 16                      NaN               NaN          NaN        NaN     NaN
# 42                    False             False      healthy    healthy     NaN
# 70                    False             False      healthy    healthy     NaN
# 71                    False             False  symptomatic        NaN     NaN
# ...                     ...               ...          ...        ...     ...
# 34380                 False             False      healthy        NaN     NaN
# 34394                   NaN               NaN          NaN        NaN     NaN
# 34407                 False             False  symptomatic        NaN     NaN
# 34413                 False             False      healthy    healthy      ok
# 34425                 False             False      healthy    healthy    good
#
#       cough_type dyspnea wheezing stridor choking congestion nothing  \
# 14           dry   False    False   False   False      False    True
# 16           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 42           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 70           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 71           NaN     NaN      NaN     NaN     NaN        NaN     NaN
# ...          ...     ...      ...     ...     ...        ...     ...
# 34380        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34394        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34407        NaN     NaN      NaN     NaN     NaN        NaN     NaN
# 34413        dry   False    False   False   False      False    True
# 34425        dry   False    False   False   False      False    True
#
#              diagnosis     severity
# 14     upper_infection         mild
# 16                 NaN          NaN
# 42                 NaN          NaN
# 70                 NaN          NaN
# 71                 NaN          NaN
# ...                ...          ...
# 34380              NaN          NaN
# 34394              NaN          NaN
# 34407              NaN          NaN
# 34413         COVID-19         mild
# 34425    healthy_cough  pseudocough
#
# [2269 rows x 18 columns]

# %%
#combining dataframes into unified dataframe
combined = pd.concat([expert_1, expert_2, expert_3, expert_4], ignore_index = True)

#dropping all NaN values 
combined.dropna(subset = ['cough_type','severity','dyspnea','wheezing','stridor','choking','congestion','nothing','diagnosis', 'quality'], inplace=True)

#verifying results
combined
# Out:
#                                       uuid  cough_detected   age  gender  \
# 11    01567151-7bb2-45ee-9aa8-a1332b5941ea          0.9820   NaN     NaN
# 16    018b40a1-c109-459a-9e31-86cbd2cb3918          0.9869   NaN     NaN
# 18    01ff40e8-63e6-4570-a463-9778ea30cad7          0.9686  24.0   other
# 28    0379c586-c500-483c-83a6-95b63afe6931          0.9916  63.0    male
# 29    038592cb-c8db-4f55-8052-e20059146cb5          0.9824  28.0    male
# ...                                    ...             ...   ...     ...
# 9066  fed255ec-4829-4f4a-b22d-9bb23f2dd89f          0.9502   NaN     NaN
# 9067  ff1234d7-7837-4ba7-842f-99fdc916baa9          0.9947  29.0    male
# 9069  ff8363d2-016d-4738-9499-4c62480886fb          0.9933   NaN  female
# 9074  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0  female
# 9075  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0    male
#
#      respiratory_condition fever_muscle_pain       status status_SSL quality  \
# 11                     NaN               NaN          NaN        NaN    good
# 16                     NaN               NaN          NaN        NaN      ok
# 18                   False             False  symptomatic        NaN    poor
# 28                    True             False     COVID-19        NaN      ok
# 29                   False             False      healthy        NaN      ok
# ...                    ...               ...          ...        ...     ...
# 9066                   NaN               NaN          NaN   COVID-19    good
# 9067                 False              True  symptomatic        NaN    good
# 9069                 False             False     COVID-19        NaN      ok
# 9074                 False             False      healthy    healthy      ok
# 9075                 False             False      healthy    healthy    good
#
#      cough_type dyspnea wheezing stridor choking congestion nothing  \
# 11          dry   False    False   False    True      False   False
# 16          wet   False    False   False   False      False    True
# 18          dry   False    False   False   False      False    True
# 28          dry   False    False   False   False      False    True
# 29          dry   False    False   False   False      False    True
# ...         ...     ...      ...     ...     ...        ...     ...
# 9066        dry   False    False   False   False      False    True
# 9067        dry   False    False   False   False      False    True
# 9069        dry   False    False   False   False      False    True
# 9074        dry   False    False   False   False      False    True
# 9075        dry   False    False   False   False      False    True
#
#             diagnosis     severity
# 11           COVID-19         mild
# 16    lower_infection         mild
# 18      healthy_cough  pseudocough
# 28      healthy_cough  pseudocough
# 29           COVID-19         mild
# ...               ...          ...
# 9066  upper_infection         mild
# 9067  upper_infection         mild
# 9069         COVID-19         mild
# 9074         COVID-19         mild
# 9075    healthy_cough  pseudocough
#
# [2585 rows x 18 columns]

# %% [markdown]
# Let's verify that the dataframe merged correctly. As per above we could see the row with index 186 had all four experts' assessments. We should now expect four rows with the same uuid number.

# %%
df.iloc[186]
# Out:
# uuid                     01567151-7bb2-45ee-9aa8-a1332b5941ea
# cough_detected                                          0.982
# age                                                       NaN
# gender                                                    NaN
# respiratory_condition                                     NaN
# fever_muscle_pain                                         NaN
# status                                                    NaN
# status_SSL                                                NaN
# quality_1                                                good
# cough_type_1                                              dry
# dyspnea_1                                               False
# wheezing_1                                              False
# stridor_1                                               False
# choking_1                                                True
# congestion_1                                            False
# nothing_1                                               False
# diagnosis_1                                          COVID-19
# severity_1                                               mild
# quality_2                                                good
# cough_type_2                                              dry
# dyspnea_2                                                True
# wheezing_2                                              False
# stridor_2                                               False
# choking_2                                               False
# congestion_2                                            False
# nothing_2                                               False
# diagnosis_2                                          COVID-19
# severity_2                                               mild
# quality_3                                                good
# cough_type_3                                              wet
# dyspnea_3                                               False
# wheezing_3                                              False
# stridor_3                                               False
# choking_3                                               False
# congestion_3                                            False
# nothing_3                                               False
# diagnosis_3                                   lower_infection
# severity_3                                             severe
# quality_4                                                good
# cough_type_4                                              dry
# dyspnea_4                                               False
# wheezing_4                                              False
# stridor_4                                               False
# choking_4                                               False
# congestion_4                                            False
# nothing_4                                                True
# diagnosis_4                                   upper_infection
# severity_4                                               mild
# Name: 186, dtype: object

# %%
row = combined['uuid'] == '01567151-7bb2-45ee-9aa8-a1332b5941ea'
true_rows = combined[row]
true_rows
# Out:
#                                       uuid  cough_detected  age gender  \
# 11    01567151-7bb2-45ee-9aa8-a1332b5941ea           0.982  NaN    NaN
# 2280  01567151-7bb2-45ee-9aa8-a1332b5941ea           0.982  NaN    NaN
# 4549  01567151-7bb2-45ee-9aa8-a1332b5941ea           0.982  NaN    NaN
# 6818  01567151-7bb2-45ee-9aa8-a1332b5941ea           0.982  NaN    NaN
#
#      respiratory_condition fever_muscle_pain status status_SSL quality  \
# 11                     NaN               NaN    NaN        NaN    good
# 2280                   NaN               NaN    NaN        NaN    good
# 4549                   NaN               NaN    NaN        NaN    good
# 6818                   NaN               NaN    NaN        NaN    good
#
#      cough_type dyspnea wheezing stridor choking congestion nothing  \
# 11          dry   False    False   False    True      False   False
# 2280        dry    True    False   False   False      False   False
# 4549        wet   False    False   False   False      False   False
# 6818        dry   False    False   False   False      False    True
#
#             diagnosis severity
# 11           COVID-19     mild
# 2280         COVID-19     mild
# 4549  lower_infection   severe
# 6818  upper_infection     mild

# %% [markdown]
# As we can see there are four rows with the same uuid number.

# %%
combined.to_csv('cleaned_coughvid_data.csv', index = False)
